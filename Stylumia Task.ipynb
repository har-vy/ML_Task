# %%
import numpy as py
import pandas as pd
data=pd.read_csv('C:/Users/Harvy/Downloads/train.csv')

# %%
len(data)
# Out:
# 891

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test=pd.read_csv('C:/Users/Harvy/Downloads/test.csv')

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# Age has null values, so we will try to fill them with suitable values.
# For that we need to look at the distribution of values
data['Age'].plot(kind='hist')

# %%
# Since ages are skewed, median would be a better measure of central tendency
data['Age'].fillna(data['Age'].median(),inplace=True)

# %%
data.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
test=pd.read_csv('C:/Users/Harvy/Downloads/test.csv')

# %%
test.isnull().any()
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# dtype: bool

# %%
# Drop unnecessary columns from dataset
data.drop(['PassengerId','Name','Ticket','Embarked','Cabin'],axis=1,inplace=True)

# %%
# Check if null values are to be replaced by mean or median
test['Fare'].plot(kind='hist')

# %%
# Since data is skewed, median is better
test['Fare'].fillna(test['Fare'].median(),inplace=True)

# %%
test['Age'].plot(kind='hist')

# %%
test['Age'].fillna(test['Age'].median(),inplace=True)

# %%
import seaborn as sb
sb.barplot(x="Sex",y="Survived",data=data)

# Females had a significantly large probability of survival as evident from the plot
# The chance of survival of a female was more than 50% than that of a male.
# Out:
# C:\Users\Harvy\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.barplot(x="Pclass",y="Survived",data=data)
# Probability of survival increased with status of the passenger
# Upper class had almost 40% more chance of survival than the lowest class

# %%
sb.barplot(x="Child",y="Survived",data=data)
# Children had a higher chance of survival

# %%
sLength=len(data['Age'])
data['Child']=pd.Series(py.random.randn(sLength), index=data.index)

# %%
threshold=18
data['Child']=py.where(data['Age']>threshold,'No','Yes')
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Child
# 0           0       3    male  22.0      1      0    7.2500    No
# 1           1       1  female  38.0      1      0   71.2833    No
# 2           1       3  female  26.0      0      0    7.9250    No
# 3           1       1  female  35.0      1      0   53.1000    No
# 4           0       3    male  35.0      0      0    8.0500    No
# 5           0       3    male  28.0      0      0    8.4583    No
# 6           0       1    male  54.0      0      0   51.8625    No
# 7           0       3    male   2.0      3      1   21.0750   Yes
# 8           1       3  female  27.0      0      2   11.1333    No
# 9           1       2  female  14.0      1      0   30.0708   Yes
# 10          1       3  female   4.0      1      1   16.7000   Yes
# 11          1       1  female  58.0      0      0   26.5500    No
# 12          0       3    male  20.0      0      0    8.0500    No
# ...

# %%
tLength=len(data['SibSp'])
data['Loner']=pd.Series(py.random.randn(tLength),index=data.index)

# %%
data['Loner']=py.where(data['SibSp']>0,'No','Yes')
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Child Loner
# 0           0       3    male  22.0      1      0    7.2500    No    No
# 1           1       1  female  38.0      1      0   71.2833    No    No
# 2           1       3  female  26.0      0      0    7.9250    No   Yes
# 3           1       1  female  35.0      1      0   53.1000    No    No
# 4           0       3    male  35.0      0      0    8.0500    No   Yes
# 5           0       3    male  28.0      0      0    8.4583    No   Yes
# 6           0       1    male  54.0      0      0   51.8625    No   Yes
# 7           0       3    male   2.0      3      1   21.0750   Yes    No
# 8           1       3  female  27.0      0      2   11.1333    No   Yes
# 9           1       2  female  14.0      1      0   30.0708   Yes    No
# 10          1       3  female   4.0      1      1   16.7000   Yes    No
# 11          1       1  female  58.0      0      0   26.5500    No   Yes
# ...

# %%
sb.barplot(x="Loner",y="Survived",data=data)
# People who were alone had lesser chance of survival than people who were part of a group

# %%
sb.barplot(x="Sex",y="Pclass",data=data)
# The probability of a male belonging to a higher class is greater than that for a female

# %%
sb.barplot(x="Sex",y="Age",data=data)
# An average male was about the same age of an average female and both were under 30
